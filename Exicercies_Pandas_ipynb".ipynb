# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreyPreobrazhenskiy/ML_Task/blob/main/Exicercies_Pandas_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Импортируйте Pandas в Jupyter Notebook.

# %%
# напишите свой код тут
import pandas as pd

# %% [markdown]
# # 1. Основыные методы работы с dataframe.

# %% [markdown]
# 2. Создайте DataFrame из словаря, где ключами будут названия столбцов, а значениями - списки значений этих столбцов.

# %%
data = {
    'Name': ['Alica', 'Boris', 'Slava', 'Dmitriy', 'Evgenia','Boris','Dmitriy'],
    'last_name':['Larin','Ivanov','Sidorov','Alekseev','Petrov', 'Lebedev', 'Aksenov'],
    'Age': [24, 27, 22, 32, 29, 44, 15],
    'City': ['Moscow', 'Moscow', 'Saint Peterburg', np.nan, 'Moscow', 'Saint Peterburg','Saint Peterburg'],
    'is_closed': [False, True, False, True, False,  True, False],
    'home_town':['Samara', 'Saratov', 'Saint Peterburg', np.nan, 'Moscow', 'Moscow','Kirov'],
    'in_group':[True, True, False, False, True, True, False],
    'male_dummy':[0, 1, 1, 1, 0, 1, 1],
    'likes_memes':[5, 8, 44, np.nan, 1, 12, 11]
}

# %%
# напишите свой код тут
import numpy as np
data = {
    'Name': ['Alica', 'Boris', 'Slava', 'Dmitriy', 'Evgenia', 'Boris', 'Dmitriy'],
    'last_name': ['Larin', 'Ivanov', 'Sidorov', 'Alekseev', 'Petrov', 'Lebedev', 'Aksenov'],
    'Age': [24, 27, 22, 32, 29, 44, 15],
    'City': ['Moscow', 'Moscow', 'Saint Peterburg', np.nan, 'Moscow', 'Saint Peterburg', 'Saint Peterburg'],
    'is_closed': [False, True, False, True, False, True, False],
    'home_town': ['Samara', 'Saratov', 'Saint Peterburg', np.nan, 'Moscow', 'Moscow', 'Kirov'],
    'in_group': [True, True, False, False, True, True, False],
    'male_dummy': [0, 1, 1, 1, 0, 1, 1],
    'likes_memes': [5, 8, 44, np.nan, 1, 12, 11]
}
df = pd.DataFrame(data)
df
# Out:
#       Name last_name  Age             City  is_closed        home_town  \
# 0    Alica     Larin   24           Moscow      False           Samara
# 1    Boris    Ivanov   27           Moscow       True          Saratov
# 2    Slava   Sidorov   22  Saint Peterburg      False  Saint Peterburg
# 3  Dmitriy  Alekseev   32              NaN       True              NaN
# 4  Evgenia    Petrov   29           Moscow      False           Moscow
# 5    Boris   Lebedev   44  Saint Peterburg       True           Moscow
# 6  Dmitriy   Aksenov   15  Saint Peterburg      False            Kirov
#
#    in_group  male_dummy  likes_memes
# 0      True           0          5.0
# 1      True           1          8.0
# 2     False           1         44.0
# 3     False           1          NaN
# 4      True           0          1.0
# 5      True           1         12.0
# 6     False           1         11.0

# %% [markdown]
# 3. Сохраните DataFrame в CSV-файл.
#
# Сохраните созданный датафрейм в файл people.csv (.to_csv()).

# %%
# напишите свой код тут
df.to_csv('people.csv')

# %% [markdown]
# 4. Загрузите данные из созданного CSV-файла people.csv в новый DataFrame с именем df и проверьте его содержимое с помощью командой pd.read_csv().
#
# Аргументов у нее очень много, критически важные:
#
# - filepath_or_buffer - текстовая строка с названием (адресом) файла
# - sep - разделитель между данными
# - header - номер строки, в которой в файле указаны названия столбцов, None, если нет
# - names - список с названиями колонок
# - index_col - или номер столбца, или список, или ничего - названия строк

# %%
# напишите свой код тут
df = pd.read_csv('people.csv')
df
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 0           0    Alica     Larin   24           Moscow      False
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   22  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes
# 0           Samara      True           0          5.0
# 1          Saratov      True           1          8.0
# 2  Saint Peterburg     False           1         44.0
# 3              NaN     False           1          NaN
# 4           Moscow      True           0          1.0
# 5           Moscow      True           1         12.0
# 6            Kirov     False           1         11.0

# %% [markdown]
# ---
#
# Есть несколько методов, которые мы используем сразу, как загрузили файл:
# - [head()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html): выводит первые 5 строк таблицы. Если задать в скобках число, то покажет ровно столько строк :)
# - [info()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html): показывает сводную информацию о таблице; сколько записей, сколько колонок, сколько непустых записей в таблице,
# - [tail()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html): работает как head(), только наоборот, печатает с конца
#
# На всякий случай, это **методы**. Их можно применять к датафрейму и столбцу, т.е. используем их так: <br>
# **[Имя датафрейма].[Название метода с круглыми скобками]**
# - df.head()
# - df.tail()
# - df.info()
#
# ----
#
#
# На основную информацию по столбцам можно посмотреть с помощью метода `.info()`. Напротив каждого названия столбца можно увидеть, сколько в нём заполненных ячеек.

# %% [markdown]
# 5. Выведите на экран первые и последние 3 строки DataFrame.

# %%
# напишите свой код тут
print(df.head(3))
# Out:
#    Unnamed: 0   Name last_name  Age             City  is_closed  \
# 0           0  Alica     Larin   24           Moscow      False
# 1           1  Boris    Ivanov   27           Moscow       True
# 2           2  Slava   Sidorov   22  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes
# 0           Samara      True           0          5.0
# 1          Saratov      True           1          8.0
# 2  Saint Peterburg     False           1         44.0

# %%
# напишите свой код тут
print(df.tail(3))
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed home_town  \
# 4           4  Evgenia    Petrov   29           Moscow      False    Moscow
# 5           5    Boris   Lebedev   44  Saint Peterburg       True    Moscow
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False     Kirov
#
#    in_group  male_dummy  likes_memes
# 4      True           0          1.0
# 5      True           1         12.0
# 6     False           1         11.0

# %% [markdown]
# 6. Получите общую информацию о DataFrame, включая количество строк и столбцов, типы данных и количество ненулевых значений. (метод info)

# %%
# напишите свой код тут
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   7 non-null      int64
#  1   Name         7 non-null      object
#  2   last_name    7 non-null      object
#  3   Age          7 non-null      int64
#  4   City         6 non-null      object
#  5   is_closed    7 non-null      bool
#  6   home_town    6 non-null      object
#  7   in_group     7 non-null      bool
#  8   male_dummy   7 non-null      int64
#  9   likes_memes  6 non-null      float64
# dtypes: bool(2), float64(1), int64(3), object(4)
# memory usage: 594.0+ bytes

# %% [markdown]
# ----------
# ### Поля
# Кроме методов, у датафреймом есть еще поля. Это справочная информация о датафрейме. Список полей
# <a href="https://pandas.pydata.org/pandas-docs/stable/reference/frame.html"> здесь </a>.
#
# Чаще всего мы используем поля:
# - **columns**: названия колонок
# - **index**: названия строк
# - **shape**: размеры датафрейма, кол-во строк и столбцов
#
# Использование:
#
# **[Имя датафрейма].[Имя поля]**
#
# - df.columns
# - df.index
# - df.shape
#
# Обратите внимание: нет круглых скобок!

# %% [markdown]
# 7. Выясните сколько в таблице строк и столбцов (метод shape).

# %%
# напишите свой код тут
df.shape
# Out:
# (7, 10)

# %% [markdown]
# 8. Выведите на экран названия всех колонок таблицы (метод columns)

# %%
# напишите свой код тут
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'last_name', 'Age', 'City', 'is_closed',
#        'home_town', 'in_group', 'male_dummy', 'likes_memes'],
#       dtype='object')

# %% [markdown]
# #2. Базовые навыки по работе с табличками

# %% [markdown]
# ### Выбор колонки
#
# Чтобы вытащить столбец, у нему нужно через квадратные скобки обратиться по имени.

# %%
# цепляем head(), чтобы не получить слишком много напечатанных имен
df['Name'].head()
# Out:
# 0      Alica
# 1      Boris
# 2      Slava
# 3    Dmitriy
# 4    Evgenia
# Name: Name, dtype: object

# %%
# обратите внимание, что в квадратные скобки мы записали только 1 объект - лист с названиями колонок.
t =df[['City', 'Name']].head()
t
# Out:
#               City     Name
# 0           Moscow    Alica
# 1           Moscow    Boris
# 2  Saint Peterburg    Slava
# 3              NaN  Dmitriy
# 4           Moscow  Evgenia

# %% [markdown]
# Можно создавать новые колонки. Например, мы можем взять все имена и фамилии, записать их через пробел и положить в новую колонку.

# %%
t['first_last_name'] = df['Name'] + ' ' + df['last_name']
t.head()
# Out:
#               City     Name   first_last_name
# 0           Moscow    Alica       Alica Larin
# 1           Moscow    Boris      Boris Ivanov
# 2  Saint Peterburg    Slava     Slava Sidorov
# 3              NaN  Dmitriy  Dmitriy Alekseev
# 4           Moscow  Evgenia    Evgenia Petrov

# %% [markdown]
# ### Выбор подряд идущих строк
#
# Если в квадратных скобках указать диапазон, то можно выбрать несколько строк, идущих друг за другом

# %%
df[:2]
# Out:
#    Unnamed: 0   Name last_name  Age    City  is_closed home_town  in_group  \
# 0           0  Alica     Larin   24  Moscow      False    Samara      True
# 1           1  Boris    Ivanov   27  Moscow       True   Saratov      True
#
#    male_dummy  likes_memes
# 0           0          5.0
# 1           1          8.0

# %%
df[1:4]
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   22  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
#
#          home_town  in_group  male_dummy  likes_memes
# 1          Saratov      True           1          8.0
# 2  Saint Peterburg     False           1         44.0
# 3              NaN     False           1          NaN

# %% [markdown]
# ---
# ### Уникальные значения и частотые таблицы
#
# Очень частой операцией является нахождение уникальных значений в колонке. В зависимости от задачи есть два метода.
# - [unique()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.unique.html): возвращает массив уникальных значений в колонке - к нему можем применять только обычный питон
# - [drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html): удаляет дублирующиеся строчки в датафрейме/колонке и возвращает соответственно датафрейм или колонку - к ним можем дальше применять пандасовские методы

# %% [markdown]
# - [value_counts()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html): считает частотную таблицу, т.е. сколько раз мы встретили значение в колонке

# %% [markdown]
# 9. Вытащите из таблички колону с городом (city), примените к ней метод, который оставит в колонке только уникальные названия городов, `.unique()`.

# %%
# напишите свой код тут
df['City'].unique()
# Out:
# array(['Moscow', 'Saint Peterburg', nan], dtype=object)

# %% [markdown]
# 10. Сколько всего городов есть в данных?

# %%
# напишите свой код тут
df['City'].nunique()
# Out:
# 2

# %% [markdown]
# 11. Найдите количество уникальных значений в каждом столбце DataFrame.

# %%
# напишите свой код тут
df.nunique()
# Out:
# Unnamed: 0     7
# Name           5
# last_name      7
# Age            7
# City           2
# is_closed      2
# home_town      5
# in_group       2
# male_dummy     2
# likes_memes    6
# dtype: int64

# %% [markdown]
# 12. Добавьте новый столбец Salary с произвольными значениями зарплат для каждого человека.

# %%
# напишите свой код тут
df['Salary'] = [400000, 190000, 130000, 70000, 230000, 150000, 100000]
df
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 0           0    Alica     Larin   24           Moscow      False
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   22  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary
# 0           Samara      True           0          5.0  400000
# 1          Saratov      True           1          8.0  190000
# 2  Saint Peterburg     False           1         44.0  130000
# 3              NaN     False           1          NaN   70000
# 4           Moscow      True           0          1.0  230000
# 5           Moscow      True           1         12.0  150000
# ...

# %% [markdown]
# 13. Измените значение возраста (столбец Age) для любого одного человека.

# %%
# напишите свой код тут
df.loc[2, 'Age'] = 64
df
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 0           0    Alica     Larin   24           Moscow      False
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   64  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary
# 0           Samara      True           0          5.0  400000
# 1          Saratov      True           1          8.0  190000
# 2  Saint Peterburg     False           1         44.0  130000
# 3              NaN     False           1          NaN   70000
# 4           Moscow      True           0          1.0  230000
# 5           Moscow      True           1         12.0  150000
# ...

# %% [markdown]
# 14. Какая доля людей закрыла профиль (is_closed)?

# %%
# напишите свой код тут
df['is_closed'].mean()
# Out:
# np.float64(0.42857142857142855)

# %% [markdown]
# 15. Отфильтруйте строки DataFrame, где возраст больше 25 лет.

# %%
# напишите свой код тут
df[df['Age'] > 25]
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   64  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
#
#          home_town  in_group  male_dummy  likes_memes  Salary
# 1          Saratov      True           1          8.0  190000
# 2  Saint Peterburg     False           1         44.0  130000
# 3              NaN     False           1          NaN   70000
# 4           Moscow      True           0          1.0  230000
# 5           Moscow      True           1         12.0  150000

# %% [markdown]
# 16. Отфильтруйте строки, где город равен "Moscow".

# %%
# напишите свой код тут
df[df['City'] == "Moscow"]
# Out:
#    Unnamed: 0     Name last_name  Age    City  is_closed home_town  in_group  \
# 0           0    Alica     Larin   24  Moscow      False    Samara      True
# 1           1    Boris    Ivanov   27  Moscow       True   Saratov      True
# 4           4  Evgenia    Petrov   29  Moscow      False    Moscow      True
#
#    male_dummy  likes_memes  Salary
# 0           0          5.0  400000
# 1           1          8.0  190000
# 4           0          1.0  230000

# %% [markdown]
# 17. Попробуйте вытащить ту же самую колонку и посчитать по ней, как часто, какой город встречается в данных, `.value_counts()`

# %%
# напишите свой код тут
df['City'].value_counts()
# Out:
# City
# Moscow             3
# Saint Peterburg    3
# Name: count, dtype: int64

# %% [markdown]
# 18. Выведите на экран $2$ самых популярных городов в датафрейме

# %%
# напишите свой код тут
df['City'].value_counts().head(2)
# Out:
# City
# Moscow             3
# Saint Peterburg    3
# Name: count, dtype: int64

# %% [markdown]
# 19. Сгруппируйте данные по столбцу City и найдите средний возраст людей для каждого города. .groupby()

# %%
# напишите свой код тут
df.groupby('City')['Age'].mean()
# Out:
# City
# Moscow             26.666667
# Saint Peterburg    41.000000
# Name: Age, dtype: float64

# %% [markdown]
# 20. Используйте loc, чтобы выбрать строки с именем "Alica" и "Evgenia" и вывести соответствующие данные.

# %%
# напишите свой код тут
df.loc[(df['Name'] == 'Alica') | (df['Name'] == 'Evgenia')]
# Out:
#    Unnamed: 0     Name last_name  Age    City  is_closed home_town  in_group  \
# 0           0    Alica     Larin   24  Moscow      False    Samara      True
# 4           4  Evgenia    Petrov   29  Moscow      False    Moscow      True
#
#    male_dummy  likes_memes  Salary
# 0           0          5.0  400000
# 4           0          1.0  230000

# %% [markdown]
# 21. Используйте loc, чтобы изменить значение зарплаты для человека по имени "Dmitriy" на 70000.

# %%
# напишите свой код тут
df.loc[df['Name'] == 'Dmitriy', 'Salary'] = 70000
df
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 0           0    Alica     Larin   24           Moscow      False
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   64  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary
# 0           Samara      True           0          5.0  400000
# 1          Saratov      True           1          8.0  190000
# 2  Saint Peterburg     False           1         44.0  130000
# 3              NaN     False           1          NaN   70000
# 4           Moscow      True           0          1.0  230000
# 5           Moscow      True           1         12.0  150000
# ...

# %% [markdown]
# 22. Используйте loc, чтобы выбрать и вывести данные всех людей старше 30 лет.

# %%
# напишите свой код тут
df.loc[df['Age'] > 30]
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 2           2    Slava   Sidorov   64  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
#
#          home_town  in_group  male_dummy  likes_memes  Salary
# 2  Saint Peterburg     False           1         44.0  130000
# 3              NaN     False           1          NaN   70000
# 5           Moscow      True           1         12.0  150000

# %% [markdown]
# 23. Сколько уникальных мужских имён встречается?

# %%
# напишите свой код тут
df.loc[df['male_dummy'] == 1, 'Name'].nunique()
# Out:
# 3

# %% [markdown]
# 24. Выведите два самых популярных мужских имени

# %%
# напишите свой код тут
df.loc[df['male_dummy'] == 1, 'Name'].value_counts().head(2)
# Out:
# Name
# Boris      2
# Dmitriy    2
# Name: count, dtype: int64

# %% [markdown]
# 25. Сколько в среднем лайков ставят под мемы девушки (колонка likes_memes)

# %%
# напишите свой код тут
df.loc[df['male_dummy'] == 0, 'likes_memes'].mean()
# Out:
# np.float64(3.0)

# %% [markdown]
# 26. Сколько суммарно лайков оставили студенты в группе с мемами?

# %%
# напишите свой код тут
df['likes_memes'].sum()
# Out:
# np.float64(81.0)

# %% [markdown]
# 27. Сколько в среднем лайков приходится на одного человека, подписанного на группу (колонка in_group)

# %%
# напишите свой код тут
df.loc[df['in_group'] == 1, 'likes_memes'].mean()
# Out:
# np.float64(6.5)

# %% [markdown]
# 28. Сколько лайков поставили люди, которые не подписаны на группу?

# %%
# напишите свой код тут
df.loc[df['in_group'] == 0, 'likes_memes'].sum()
# Out:
# np.float64(55.0)

# %% [markdown]
# 29. Выведите на экран колонки, в которых нет ни одного пропуска.

# %%
# напишите свой код тут
df.columns[df.notna().all()]
# Out:
# Index(['Unnamed: 0', 'Name', 'last_name', 'Age', 'is_closed', 'in_group',
#        'male_dummy', 'Salary'],
#       dtype='object')

# %% [markdown]
# 30.  Сейчас число лайков измеряется по шкале от $0$ до $44$. В машинном обучении довольно часто возникает желание поменять у данных шкалу, в которой они измерены. Такая процедура называется скалированием. Давайте переведём лайки с отрезка $[0, 44]$ на отрезок $[0, 1]$. Делать это будем по формуле:
#
#         x_new = (x-min)/(max-min)
#
#         min = минимальный элемент в столбце
#         max = максимальный элемент в столбце
#
# Получившийся результат запишем в колонку `like_memes_scal`.

# %%
# напишите свой код тут
df['like_memes_scal'] = (df['likes_memes'] - df['likes_memes'].min()) / (df['likes_memes'].max() - df['likes_memes'].min())
df
# Out:
#    Unnamed: 0     Name last_name  Age             City  is_closed  \
# 0           0    Alica     Larin   24           Moscow      False
# 1           1    Boris    Ivanov   27           Moscow       True
# 2           2    Slava   Sidorov   64  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev   32              NaN       True
# 4           4  Evgenia    Petrov   29           Moscow      False
# 5           5    Boris   Lebedev   44  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   15  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary  like_memes_scal
# 0           Samara      True           0          5.0  400000         0.093023
# 1          Saratov      True           1          8.0  190000         0.162791
# 2  Saint Peterburg     False           1         44.0  130000         1.000000
# 3              NaN     False           1          NaN   70000              NaN
# ...

# %% [markdown]
# 31. Найдите суммарную зарплату для каждого города

# %%
# напишите свой код тут
df.groupby('City')['Salary'].sum()
# Out:
# City
# Moscow             820000
# Saint Peterburg    350000
# Name: Salary, dtype: int64

# %% [markdown]
# 32. Используйте where, чтобы заменить все значения возраста, которые меньше 25, на NaN.

# %%
# напишите свой код тут
df['Age'] = df['Age'].where(df['Age'] >= 25)
df
# Out:
#    Unnamed: 0     Name last_name   Age             City  is_closed  \
# 0           0    Alica     Larin   NaN           Moscow      False
# 1           1    Boris    Ivanov  27.0           Moscow       True
# 2           2    Slava   Sidorov  64.0  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev  32.0              NaN       True
# 4           4  Evgenia    Petrov  29.0           Moscow      False
# 5           5    Boris   Lebedev  44.0  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   NaN  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary  like_memes_scal
# 0           Samara      True           0          5.0  400000         0.093023
# 1          Saratov      True           1          8.0  190000         0.162791
# 2  Saint Peterburg     False           1         44.0  130000         1.000000
# 3              NaN     False           1          NaN   70000              NaN
# ...

# %% [markdown]
# 33. Используйте where, чтобы заменить все значения зарплаты, которые меньше 60000, на 12000.

# %%
# напишите свой код тут
df['Salary'] = df['Salary'].where(df['Salary'] >= 60000, 12000)
df
# Out:
#    Unnamed: 0     Name last_name   Age             City  is_closed  \
# 0           0    Alica     Larin   NaN           Moscow      False
# 1           1    Boris    Ivanov  27.0           Moscow       True
# 2           2    Slava   Sidorov  64.0  Saint Peterburg      False
# 3           3  Dmitriy  Alekseev  32.0              NaN       True
# 4           4  Evgenia    Petrov  29.0           Moscow      False
# 5           5    Boris   Lebedev  44.0  Saint Peterburg       True
# 6           6  Dmitriy   Aksenov   NaN  Saint Peterburg      False
#
#          home_town  in_group  male_dummy  likes_memes  Salary  like_memes_scal
# 0           Samara      True           0          5.0  400000         0.093023
# 1          Saratov      True           1          8.0  190000         0.162791
# 2  Saint Peterburg     False           1         44.0  130000         1.000000
# 3              NaN     False           1          NaN   70000              NaN
# ...

# %% [markdown]
# 34. Создайте многоуровневый индекс 'City' и 'Name'

# %%
# напишите свой код тут
df_multi=df.set_index(['City', 'Name'])
df_multi
# Out:
#                          Unnamed: 0 last_name   Age  is_closed  \
# City            Name
# Moscow          Alica             0     Larin   NaN      False
#                 Boris             1    Ivanov  27.0       True
# Saint Peterburg Slava             2   Sidorov  64.0      False
# NaN             Dmitriy           3  Alekseev  32.0       True
# Moscow          Evgenia           4    Petrov  29.0      False
# Saint Peterburg Boris             5   Lebedev  44.0       True
#                 Dmitriy           6   Aksenov   NaN      False
#
#                                home_town  in_group  male_dummy  likes_memes  \
# City            Name
# Moscow          Alica             Samara      True           0          5.0
#                 Boris            Saratov      True           1          8.0
# Saint Peterburg Slava    Saint Peterburg     False           1         44.0
# NaN             Dmitriy              NaN     False           1          NaN
# ...

# %% [markdown]
# 35. Используйте xs, чтобы выбрать данные для города "Moscow"

# %%
# напишите свой код тут
df_multi.xs('Moscow', level='City')
# Out:
#          Unnamed: 0 last_name   Age  is_closed home_town  in_group  \
# Name
# Alica             0     Larin   NaN      False    Samara      True
# Boris             1    Ivanov  27.0       True   Saratov      True
# Evgenia           4    Petrov  29.0      False    Moscow      True
#
#          male_dummy  likes_memes  Salary  like_memes_scal
# Name
# Alica             0          5.0  400000         0.093023
# Boris             1          8.0  190000         0.162791
# Evgenia           0          1.0  230000         0.000000

# %% [markdown]
# 36. Используйте xs, чтобы выбрать данные для человека с именем "Boris"

# %%
# напишите свой код тут
df_multi.xs('Boris', level='Name')
# Out:
#                  Unnamed: 0 last_name   Age  is_closed home_town  in_group  \
# City
# Moscow                    1    Ivanov  27.0       True   Saratov      True
# Saint Peterburg           5   Lebedev  44.0       True    Moscow      True
#
#                  male_dummy  likes_memes  Salary  like_memes_scal
# City
# Moscow                    1          8.0  190000         0.162791
# Saint Peterburg           1         12.0  150000         0.255814

# %% [markdown]
# 37. Вычислите суммарную зарплату всех людей.

# %%
# напишите свой код тут
df['Salary'].sum()
# Out:
# np.int64(1240000)

# %% [markdown]
# 38. Вычислите среднюю зарплату всех людей нашего Dataframe.

# %%
# напишите свой код тут
df['Salary'].mean()
# Out:
# np.float64(177142.85714285713)

# %% [markdown]
# 39. Вычислите медиану возраста сотрудников.

# %%
# напишите свой код тут
df['Age'].median()
# Out:
# 32.0

# %% [markdown]
# 40. Вычислите стандартное отклонение зарплаты

# %%
# напишите свой код тут
df['Salary'].std()
# Out:
# 114413.61890297933

# %% [markdown]
# 41. Вычислите минимальную и максимальную зарплату

# %%
# напишите свой код тут
min_sal = df['Salary'].min()
max_sal = df['Salary'].max()

# %% [markdown]
# 42. Вычислите минимальный и максимальный возраст сотрудников.

# %%
# напишите свой код тут
min_age = df['Age'].min()
max_age = df['Age'].max()
